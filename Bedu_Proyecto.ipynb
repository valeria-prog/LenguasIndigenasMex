# %% [markdown]
# <a href="https://colab.research.google.com/github/valeria-prog/LenguasIndigenasMex/blob/main/Bedu_Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto Bedu : Lenguas Indígenas en México

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Comparativo de los Censos de población y vivienda sobre la Población 3 años y más hablantes de  lengu.csv', index_col=0)
df.head(69)
# Out:
#                       Autodenominacion  Censo_2010 Encuesta_Intercensal_2015  \
# Lengua
# Náhuatl      Mexihkatlahtolli (náhuatl)  1,586,884                 1,725,620
# Maya                  MaayatꞋaan (maya)    795,499                   859,607
# Tseltal           BatsꞋil kꞋop Tseltal     474,298                   556,720
# Tsotsil            BatsꞋi kꞋop Tsotsil     429,168                   487,898
# Mixteco            TuꞋun Savi (mixteco)    496,038                   517,665
# ...                                 ...        ...                       ...
# Oluteco    Yaak avu (popoluca de Oluta)         50                        90
# Kiliwa                           Kiliwa         46                       194
# Ayapaneco        Numte oote (ayapaneco)         21                        24
# Kickapoo                       Kickapoo        446                       124
# Awakateko           QaꞋyool (awakateko)      1,997                        17
#
#           Censo_2020
# Lengua
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
